# %%
import pandas

# %%
fatalities = pandas.Series(index=['Australia', 'Albania',
                                  "Burkino Faso",'Libya', 'Monaco'], 
                           data=[5.4, 15.1, 30, 73.4, "-"]
                          )

# %%
fatalities
# Out:
# Australia        5.4
# Albania         15.1
# Burkino Faso      30
# Libya           73.4
# Monaco             -
# dtype: object

# %%
fatalities == "-"
# Out:
# Australia       False
# Albania         False
# Burkino Faso    False
# Libya           False
# Monaco           True
# dtype: bool

# %%
data_invalid = fatalities == "-"
fatalities[data_invalid]
# Out:
# Monaco    -
# dtype: object

# %%
fatalities[data_invalid] = 0

# %%
fatalities
# Out:
# Australia        5.4
# Albania         15.1
# Burkino Faso      30
# Libya           73.4
# Monaco             0
# dtype: object

# %%
fatalities.dtype
# Out:
# dtype('O')

# %%
fatalities.astype(float)
# Out:
# Australia        5.4
# Albania         15.1
# Burkino Faso    30.0
# Libya           73.4
# Monaco           0.0
# dtype: float64

# %%
fatalities.astype(int)
# Out:
# Australia        5
# Albania         15
# Burkino Faso    30
# Libya           73
# Monaco           0
# dtype: int64

# %%
fatalities2 = fatalities.astype(int)
fatalities2
# Out:
# Australia        5
# Albania         15
# Burkino Faso    30
# Libya           73
# Monaco           0
# dtype: int64

# %%
fatalities3 = fatalities[fatalities > 0]

# %%
fatalities = fatalities.replace("-", 0)

# %%
fatalities.min()

# %%
fatalities.idxmin()

# %%
fatalities.idxmax()

# %%
fatalities.mean(), fatalities.median(), fatalities.std()

# %%
population = pandas.Series(index=['Australia', 'Burkino Faso', 'Libya'],
                          data=[24000000, 19000000, 6300000]
                          )

# %%
population
# Out:
# Australia       24000000
# Burkino Faso    19000000
# Libya            6300000
# dtype: int64

# %%
population * fatalities / 100000
# Out:
# Albania            NaN
# Australia         1296
# Burkino Faso      5700
# Libya           4624.2
# Monaco             NaN
# dtype: object

# %%
fatality_count = (population * fatalities / 100000).astype(float)
fatality_count
# Out:
# Albania            NaN
# Australia       1296.0
# Burkino Faso    5700.0
# Libya           4624.2
# Monaco             NaN
# dtype: float64

# %%
fatality_count.isnull()
# Out:
# Albania          True
# Australia       False
# Burkino Faso    False
# Libya           False
# Monaco           True
# dtype: bool

# %%
fatality_count[fatality_count.notnull()]
# Out:
# Australia       1296.0
# Burkino Faso    5700.0
# Libya           4624.2
# dtype: float64

# %%
sydtrains = pandas.read_csv('data/sydtrains.csv', 
                            index_col=1,
                            thousands=","
                           )
sydtrains
# Out:
#                                                LINE  YEAR SURVEY_DATE_USED  \
# STATION
# Central                                         CBD  2014        6/05/2014
# Town Hall                                       CBD  2014        7/05/2014
# Wynyard                                         CBD  2014       20/05/2014
# Parramatta                                  Western  2014       19/11/2014
# North Sydney                            North Shore  2014       19/08/2014
# Redfern                                         CBD  2014        1/05/2014
# Chatswood                               North Shore  2014       19/08/2014
# Bondi Junction                      Eastern Suburbs  2014        2/09/2014
# Strathfield                              Inner West  2014        9/09/2014
# Circular Quay                                   CBD  2014       22/05/2014
# Martin Place                                    CBD  2014       27/05/2014
# ...

# %%
sydtrains.IN_0200_0600
# Out:
# STATION
# Central                   940
# Town Hall                 880
# Wynyard                   590
# Parramatta                660
# North Sydney              270
# Redfern                   250
# Chatswood                 210
# Bondi Junction            210
# Strathfield               190
# Circular Quay             200
# Martin Place              200
# Hurstville                160
# St Leonards               170
# Blacktown                 190
# Burwood                   140
# Kings Cross               120
# Hornsby                   210
# Ashfield                  100
# Kogarah                    90
# Lidcombe                  100
# Auburn                    130
# Museum                    100
# Epping                    170
# Macquarie University      100
# St James                  100
# Rockdale                   90
# Cabramatta                150
# Bankstown                  80
# Liverpool                 150
# Sutherland                140
# ...

# %%
len(sydtrains)
# Out:
# 3367

# %%
sydtrains.count()
# Out:
# LINE                3367
# YEAR                3367
# SURVEY_DATE_USED    3367
# WHETHER_SURVEYED    3367
# IN_0200_0600        3367
# OUT_0200_0600       3367
# IN_0600_0930        3367
# OUT_0600_0930       3367
# IN_0930_1500        3367
# OUT_0930_1500       3367
# IN_1500_1830        3367
# OUT_1500_1830       3367
# IN_1830_0200        3367
# OUT_1830_0200       3367
# IN_24_HOURS         3367
# OUT_24_HOURS        3367
# RANK                3367
# STATION_SORT_ID     3367
# dtype: int64

# %%
trains2014 = sydtrains[sydtrains.YEAR == 2014]
trains2014
# Out:
#                                                  LINE  YEAR SURVEY_DATE_USED  \
# STATION
# Central                                           CBD  2014        6/05/2014
# Town Hall                                         CBD  2014        7/05/2014
# Wynyard                                           CBD  2014       20/05/2014
# Parramatta                                    Western  2014       19/11/2014
# North Sydney                              North Shore  2014       19/08/2014
# Redfern                                           CBD  2014        1/05/2014
# Chatswood                                 North Shore  2014       19/08/2014
# Bondi Junction                        Eastern Suburbs  2014        2/09/2014
# Strathfield                                Inner West  2014        9/09/2014
# Circular Quay                                     CBD  2014       22/05/2014
# Martin Place                                      CBD  2014       27/05/2014
# ...

# %%
sydtrains.LINE.unique()
# Out:
# array(['CBD', 'Western', 'North Shore', 'Eastern Suburbs', 'Inner West',
#        'Illawarra', 'South', 'Northern via Strathfield',
#        'Northern via Macquarie Park', 'Bankstown', 'Airport', 'East Hills',
#        'Central Coast', 'Olympic Park', 'South Coast', 'Blue Mountains',
#        'Newcastle', 'Hunter', 'Carlingford', 'Southern Highlands'], dtype=object)

# %%
sydtrains.LINE.nunique()
# Out:
# 20

# %% [markdown]
# And while we are doing things that look like SQL, here's
# what
#
#   `select * from trains where line like '%C%'`
#
# would be

# %%
sydtrains[sydtrains.LINE.str.contains('C')].LINE.unique()
# Out:
# array(['CBD', 'Central Coast', 'South Coast', 'Carlingford'], dtype=object)

# %% [markdown]
# Anyway, back on topic...

# %%
sydtrains.index.unique()
# Out:
# array(['Central', 'Town Hall', 'Wynyard', 'Parramatta', 'North Sydney',
#        'Redfern', 'Chatswood', 'Bondi Junction', 'Strathfield',
#        'Circular Quay', 'Martin Place', 'Hurstville', 'St Leonards',
#        'Blacktown', 'Burwood', 'Kings Cross', 'Hornsby', 'Ashfield',
#        'Kogarah', 'Lidcombe', 'Auburn', 'Museum', 'Epping',
#        'Macquarie University', 'St James', 'Rockdale', 'Cabramatta',
#        'Bankstown', 'Liverpool', 'Sutherland', 'Fairfield', 'Westmead',
#        'Penrith', 'Mount Druitt', 'Edgecliff', 'Mascot', 'Eastwood',
#        'Milsons Point', 'Newtown', 'Campsie', 'Seven Hills', 'Rhodes',
#        'Domestic Airport', 'Granville', 'West Ryde', 'Campbelltown',
#        'Green Square', 'Gordon', 'Sydenham', 'Merrylands', 'Artarmon',
#        'Gosford', 'Glenfield', 'Turramurra', 'Lakemba', 'St Marys',
#        'Wolli Creek', 'Woy Woy', 'Mortdale', 'Revesby', 'Riverwood',
#        'Olympic Park', 'Lindfield', 'Marrickville', 'Macquarie Park',
# ...

# %%
trains2014.IN_0930_1500.dtype
# Out:
# dtype('int64')

# %%
trains2014.dtypes
# Out:
# LINE                object
# YEAR                 int64
# SURVEY_DATE_USED    object
# WHETHER_SURVEYED    object
# IN_0200_0600         int64
# OUT_0200_0600        int64
# IN_0600_0930         int64
# OUT_0600_0930        int64
# IN_0930_1500         int64
# OUT_0930_1500        int64
# IN_1500_1830         int64
# OUT_1500_1830        int64
# IN_1830_0200         int64
# OUT_1830_0200        int64
# IN_24_HOURS          int64
# OUT_24_HOURS         int64
# RANK                 int64
# STATION_SORT_ID      int64
# dtype: object

# %%
trains2014.IN_24_HOURS
# Out:
# STATION
# Central                     97110
# Town Hall                   89620
# Wynyard                     60200
# Parramatta                  34960
# North Sydney                28610
# Redfern                     25680
# Chatswood                   22200
# Bondi Junction              21880
# Strathfield                 20710
# Circular Quay               20630
# Martin Place                20630
# Hurstville                  18290
# St Leonards                 17590
# Blacktown                   16560
# Burwood                     14990
# Kings Cross                 12870
# Hornsby                     12250
# Ashfield                    11200
# Kogarah                     11100
# Lidcombe                    10910
# Auburn                      10890
# Museum                      10860
# Epping                      10570
# Macquarie University        10090
# St James                     9850
# Rockdale                     9640
# Cabramatta                   8730
# ...

# %%
trains2014.IN_24_HOURS.idxmax()
# Out:
# 'Central'

# %%
trains2014.OUT_24_HOURS.idxmax()
# Out:
# 'Central'

# %%
trains2014.IN_24_HOURS.idxmin()
# Out:
# 'Bell'

# %%
trains2014.OUT_24_HOURS.idxmin()
# Out:
# 'Bell'

# %%
trains2014.IN_24_HOURS.min()
# Out:
# 0

# %%
trains2014[trains2014.IN_24_HOURS == 0]
# Out:
#                                         LINE  YEAR SURVEY_DATE_USED  \
# STATION
# Bell                          Blue Mountains  2014                0
# Hilldale                              Hunter  2014        3/06/2009
# Kembla Grange Racecourse         South Coast  2014       15/02/1996
# Lochinvar                             Hunter  2014        3/06/2009
# Lysaghts                         South Coast  2014       12/11/2013
# Mindaribba                            Hunter  2014        3/06/2009
# Penrose                   Southern Highlands  2014       25/05/2010
# Wallarobba                            Hunter  2014        3/06/2009
# Wingello                  Southern Highlands  2014       25/05/2010
# Wirragulla                            Hunter  2014        3/06/2009
# Zig Zag                       Blue Mountains  2014        9/10/2014
#
#                          WHETHER_SURVEYED  IN_0200_0600  OUT_0200_0600  \
# STATION
# ...

# %%
trains2014.to_csv('2014-data.csv')

# %%
trains2014[ ['IN_0200_0600', 'OUT_0200_0600'] ]
# Out:
#                           IN_0200_0600  OUT_0200_0600
# STATION
# Central                            940            920
# Town Hall                          880            880
# Wynyard                            590            570
# Parramatta                         660            330
# North Sydney                       270            270
# Redfern                            250            250
# Chatswood                          210            200
# Bondi Junction                     210            210
# Strathfield                        190            190
# Circular Quay                      200            200
# Martin Place                       200            190
# Hurstville                         160            160
# St Leonards                        170            170
# Blacktown                          190            210
# Burwood                            140            140
# Kings Cross                        120            120
# ...

# %%
trains2014.loc['Central']
# Out:
# LINE                      CBD
# YEAR                     2014
# SURVEY_DATE_USED    6/05/2014
# WHETHER_SURVEYED          Yes
# IN_0200_0600              940
# OUT_0200_0600             920
# IN_0600_0930            10390
# OUT_0600_0930           42070
# IN_0930_1500            21400
# OUT_0930_1500           30150
# IN_1500_1830            45370
# OUT_1500_1830           16270
# IN_1830_0200            19010
# OUT_1830_0200            7700
# IN_24_HOURS             97110
# OUT_24_HOURS            97110
# RANK                        1
# STATION_SORT_ID           101
# Name: Central, dtype: object

# %%
trains2014.describe()
# Out:
#          YEAR  IN_0200_0600  OUT_0200_0600  IN_0600_0930  OUT_0600_0930  \
# count   308.0    308.000000     308.000000    308.000000     308.000000
# mean   2014.0     52.142857      33.084416   1176.266234    1130.422078
# std       0.0    107.324369      90.671936   1626.940742    4482.948456
# min    2014.0      0.000000       0.000000      0.000000       0.000000
# 25%    2014.0     10.000000       0.000000     97.500000      20.000000
# 50%    2014.0     20.000000      10.000000    520.000000     150.000000
# 75%    2014.0     50.000000      30.000000   1650.000000     602.500000
# max    2014.0    940.000000     920.000000  10390.000000   43210.000000
#
#        IN_0930_1500  OUT_0930_1500  IN_1500_1830  OUT_1500_1830  IN_1830_0200  \
# count    308.000000     308.000000    308.000000     308.000000    308.000000
# mean     777.954545     809.545455   1226.818182    1131.785714    385.194805
# std     1901.729550    2470.684364   4508.392060    1869.717983   1835.041549
# ...

# %%
trains2014.LINE.value_counts()
# Out:
# South Coast                    34
# Western                        29
# Hunter                         27
# Illawarra                      26
# Blue Mountains                 22
# North Shore                    21
# Bankstown                      21
# East Hills                     19
# Southern Highlands             18
# Newcastle                      17
# Central Coast                  14
# South                          11
# Inner West                     11
# Northern via Macquarie Park     8
# Northern via Strathfield        8
# CBD                             8
# Carlingford                     6
# Airport                         4
# Eastern Suburbs                 3
# Olympic Park                    1
# Name: LINE, dtype: int64
